# %%
import numpy as np
import matplotlib.pyplot as plt
i=6
plt.rc('text', usetex=True)
amp_list = np.load(f'data/500k_rot_cut/amp_list.npy')
rad_list = np.load(f'data/500k_rot_cut/rad_list.npy')
k_list = np.load(f'data/500k_rot_cut/k_list.npy')
plt.hist(k_list, bins=25, weights=amp_list, density=False, histtype='step', label='Amplitude')
# plt.hist(k_list, bins=25, weights=weighted_amp_list, density=False, histtype='step', label='Weighted amplitude')
#plt.plot(k_list, amp_list, 'o', markersize=1, label='Normalized Amplitude')
#plt.plot(k_list, rad_list, 'o', markersize=1, label='Radiation Only', color='orange')
plt.legend()
#plt.ylim(0,0.2)
plt.xlabel(r"$\eta$")
plt.ylabel(r"$\textrm{Normalized amplitude}$")
plt.title(rf"$\textrm{{{amp_list.shape[0]} events}}$; ${500+250*i} \textrm{{GeV}} < m_{{jj}} < {750+250*i} \textrm{{GeV}}$")
#plt.savefig(f'plots/500k_rot/amp_list_real_500k_k11.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
i=6
plt.rc('text', usetex=True)
amp_list = np.load(f'data/500k_rot_cut/amp_list.npy')
rad_list = np.load(f'data/500k_rot_cut/rad_list.npy')
k_list = np.load(f'data/500k_rot_cut/k_list.npy')
plt.hist(k_list, bins=25, weights=rad_list, density=False, histtype='step', label='Antenna Function')
# plt.hist(k_list, bins=25, weights=weighted_amp_list, density=False, histtype='step', label='Weighted amplitude')
#plt.plot(k_list, amp_list, 'o', markersize=1, label='Normalized Amplitude')
#plt.plot(k_list, rad_list/10000, 'o', markersize=1, label='Antenna Function', color='orange')
plt.legend()
#plt.ylim(0,0.2)
plt.xlabel(r"$\eta$")
#plt.ylabel(r"$\textrm{Normalized amplitude}$")
plt.title(rf"$\textrm{{{amp_list.shape[0]} events}}$; ${500+250*i} \textrm{{GeV}} < m_{{jj}} < {750+250*i} \textrm{{GeV}}$")
#plt.savefig(f'plots/500k_rot/amp_list_real_500k_k11.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
i=6
plt.rc('text', usetex=True)
amp_list = np.load(f'data/500k_rot_cut/amp_list.npy')
rad_list = np.load(f'data/500k_rot_cut/rad_list.npy')
k_list = np.load(f'data/500k_rot_cut/k_list.npy')
asym_list = np.load(f'data/500k_rot_cut/asym_list.npy')
plt.hist(k_list, bins=25, weights=asym_list/1e4, density=False, histtype='step', label=rf"$\cos(2\phi)$")
# plt.hist(k_list, bins=25, weights=weighted_amp_list, density=False, histtype='step', label='Weighted amplitude')
#plt.plot(k_list, amp_list, 'o', markersize=1, label='Normalized Amplitude')
#plt.plot(k_list, asym_list/10000, 'o', markersize=1, label=rf"$\cos(2\phi)$", color='red')
plt.legend()
#plt.ylim(0,0.2)
plt.xlabel(r"$\eta$")
#plt.ylabel(r"$\textrm{Normalized amplitude}$")
plt.title(rf"$\textrm{{{amp_list.shape[0]} events}}$; ${500+250*i} \textrm{{GeV}} < m_{{jj}} < {750+250*i} \textrm{{GeV}}$")
#plt.savefig(f'plots/500k_rot/amp_list_real_500k_k11.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
i=5
plt.rc('text', usetex=True)
amp_list = np.load(f'data/500k_rot_cut/amp_list_noNgrid.npy')
k_list = np.load(f'data/500k_rot_cut/k_list_noNgrid.npy')
print(f'amp_list shape: {amp_list.shape}')
plt.hist(k_list, bins=25, weights=-amp_list, density=False, histtype='step', label='Amplitude')
# plt.hist(k_list, bins=25, weights=weighted_amp_list, density=False, histtype='step', label='Weighted amplitude')
# plt.plot(k_list, amp_list, 'o', markersize=1, label='Amplitude')
plt.legend()
#plt.ylim(0,0.5)
plt.xlabel(r"$\eta$")
plt.ylabel(r"$\textrm{Normalized amplitude}$")
plt.title(rf"$\textrm{{1k events}}$; ${500+250*i} \textrm{{GeV}} < m_{{jj}} < {750+250*i} \textrm{{GeV}}$")
#plt.savefig(f'plots/500k_rot/amp_list_real_500k_k11.png')
plt.show()
print(amp_list[:10])
# Out:
# amp_list shape: (1000,)
# [-0.14121206 -0.00454047 -0.10847355 -0.18231807 -0.1767507  -0.20461094
#   0.01875281 -0.02682447 -0.1095927  -0.0169636 ]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('text', usetex=True)
for i in range(9):
    amp_list = np.load(f'data/500k_rot/amp_list_real_500k_k1_eta_5{i+1}.npy')
    k_list = np.load(f'data/500k_rot/k_list_real_500k_k1_eta_5{i+1}.npy')
    plt.hist(k_list, bins=30, weights=amp_list, density=True)
    #plt.ylim(0,1)
    plt.xlabel(r"$\eta$")
    plt.ylabel(r"$\textrm{Weighted amplitude}$")
    plt.title(rf"$\textrm{{500k events}}$; ${500+250*i} \textrm{{GeV}} < m_{{jj}} < {750+250*i} \textrm{{GeV}}$")
    plt.savefig(f'plots/500k_rot/amp_list_real_500k_k1_eta_5{i+1}.png')
    plt.show()

# %%
i=6
amp_list = np.load(f'data/amp_list_real_500k_k2.npy')
k_list = np.load(f'data/k_list_real_500k_k2.npy')
plt.hist(k_list, bins=30, weights=amp_list, density=True)
#plt.ylim(0,1)
plt.xlabel(r"$\eta$")
plt.ylabel(r"$\textrm{Weighted amplitude}$")
plt.title(rf"$\textrm{{500k events}}$; ${500+250*i} \textrm{{GeV}} < m_{{jj}} < {750+250*i} \textrm{{GeV}}$")
plt.show()

# %%
i=6
amp_list = np.load(f'data/asym_list.npy')
k_list = np.load(f'data/asym_k1.npy')
plt.hist(k_list, bins=30, weights=amp_list, density=True)
#plt.ylim(0,1)
plt.xlabel(r"$\eta$")
plt.ylabel(r"$\textrm{Weighted amplitude}$")
plt.title(rf"$\textrm{{500k events}}$; ${500+250*i} \textrm{{GeV}} < m_{{jj}} < {750+250*i} \textrm{{GeV}}$")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('text', usetex=True)

for i in range(9):
    # Load data
    amp_list_combined = np.load(f'data/amp_list_channel_{i+1}_500k.npy')
    # Sum along axis 1 and normalize
    summed = np.sum(amp_list_combined, axis=1) / 50
    # Define eta bins
    eta_list = np.linspace(-3, 3, 50)
    # Create a new figure for each channel
    plt.figure()
    # Plot histogram
    plt.hist(eta_list, bins=eta_list, weights=summed)
    plt.ylim(0, 1)
    # Add labels and title
    plt.xlabel(r"$\eta$")
    plt.ylabel(r"$\textrm{Weighted amplitude}$")
    plt.title(rf"$\textrm{{500k events}}$; ${500+250*i} \textrm{{GeV}} < m_{{jj}} < {750+250*i} \textrm{{GeV}}$")
    plt.savefig(f"plots/500k_rot/amp_hist_channel_{i+1}_500k.png")
# Show all figures
plt.show()
